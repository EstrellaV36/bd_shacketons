# %% [markdown]
# - Considerar bus y ferry (terrestre y maritimo), en diferentes tablas, verémos para ponerlo todo en una sola tabla
# - Agregar tabla de comentarios
# - Agregar opción selección ON/OFF/AMBAS
